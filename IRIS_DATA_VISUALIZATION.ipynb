# %% [markdown]
# <a href="https://colab.research.google.com/github/merlinecatharine/MACHINE-LEARNING-PROJECT/blob/main/IRIS_DATA_VISUALIZATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IRIS DATA VISUALIZATION**

# %% [markdown]
# Used libraries:
# ---
#
#
# 1.   numpy
# 2.   pandas
# 3.   matplotlib
# 4.   seaborn

# %% [markdown]
# TABLE OF CONTENTS
# ---
# 1.IMPORTING REQUIRED LIBRARIES
#
# 2.LOADING IRIS DATASET
#
# 3.IRIS DATASET
#
# 4.MISSING DATA?
#
# 5.WHICH SPECIES HAVE LARGE SEPAL_LENGTH?
#
# 6.WHICH SPECIES HAVE LARGE SEPAL_WIDTH?
#
# 7.WHICH SPECIES HAVE LARGE PETAL_LENGTH?
#
# 8.WHICH SPECIES HAVE LARGE PETAL_WIDTH?
#
# 9.WHAT IS THE NUMBER OF COUNT OF SPECIES?
#
# 10.UNI-VARIATE ANALYSIS:
#
# 10.1.COMPARE SPECIES BASED ON SEPALS?
#
# 10.2.COMPARE SPECIES BASED ON PETALS?
#
# 11.BI-VARIATE ANALYSIS
#
# 12.DISTRIBUTION OF SPECIES
#
# 13.HISTOGRAM AND PROBABILITY DISTRIBUTION FUNCTION

# %% [markdown]
# Importing required libraries
# ---

# %%
#importing 
import seaborn as sns  #importing seaborn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Loading iris dataset
# ---

# %%
#loading dataset
path='/content/IRIS.csv'
df=pd.read_csv('IRIS.csv')

# %% [markdown]
# iris dataset
# ---

# %%
#printing dataset
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#printing head() 
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#printing tail()
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.info()  #information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# MISSING DATA?
# ---

# %%
#checking for missing data
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# **Dataset is clear**
#
# > no missing data

# %% [markdown]
# WHICH SPECIES HAVE LARGE SEPAL_LENGTH?
# ---
# For knowing we are using distplot across species(setosa,versicolor,verginica)

# %%
sns.displot(data=df, x="sepal_length", col="species", kde=True) #DISTRIBUTED PLOT WITH SEPAL_LENGTH

# %% [markdown]
# SOLUTION:IRIS-VIRGINICA HAS HIGH SEPAL LENGTH
#
# ---
#
# From the distributed plot we can see that species iris-virginica has more sepal_length when compared to iris-versicolor and iris-setosa.It is around 6.5 .whereas setosa sepal length is around 5.0 and versicolor is around 5.5-6.0.

# %% [markdown]
# WHICH SPECIES HAVE LARGE SEPAL_WIDTH?
# ---
# For knowing this we can use distplot.

# %%
sns.displot(data=df, x="sepal_width", col="species", kde=True)  #DISTRIBUTED PLOT WITH SEPAL_WIDTH

# %% [markdown]
# SOLUTION: IRIS-SETOSA HAVE HIGH SEPAL_WIDTH
#
# ---
# From the above distributed plot we can see that iris-setosa have more sepal_width than other two.
# we can see that iris-versicolor and iris-virginica have their sepal widths around 2.0 to 3.0 whereas iris-setosa have its sepal_width around 3.0 to 4.5

# %% [markdown]
# WHICH SPICIES HAVE LARGE PETAL_LENGTH?
# ---

# %%
sns.displot(data=df, x="petal_length", col="species", kde=True)  #DISTRIBUTED PLOT TO KNOW WITH PETAL_LENGTH

# %% [markdown]
# SOLUTION:IRIS-VIRGINICA HAVE LARGE PETAL_LENGTH
#
# ---
# From the distributed plot we can see that iris-virginica have the lage petal_length compared to other species.Iris-setosa most flower petal_length is around 1-2.And iris-versicolor's petal_length is around 3-5 . iris-virginica have its petal_length around 4-7 . so iris-virginica have large petal_length

# %% [markdown]
# WHICH SPECIES HAVE LARGE PETAL_WIDTH?
# ---

# %%
sns.displot(data=df, x="petal_width", col="species", kde=True) #DISTRIBUTED PLOT USING PETAL_WIDTH

# %% [markdown]
# SOLUTION:IRIS-VIRGINICA HAVE LARGE PETAL_WIDTH.
#
# ---
# We can see from the plot that iris-setosa's petal_width is around 0.0 to 0.5 and iris-versicolor is around 1.0 to 2.0 ,iris-virginica have large petal_width of around 1.5 to 2.5. so, iris-virginica have more petal_width.

# %% [markdown]
# WHAT IS THE NUMBER OF COUNT OF SPECIES?
# ---

# %%
sns.countplot(data=df,x='species',hue='species')   #count plot

# %% [markdown]
# SOLUTION:WE HAVE 50 COUNT ON EACH SPECIES
#
# ---
# We have 50 iris-setosa, 50 iris-versicolor ,50 iris-virginica
# In this dataset we took 150 iris flowers .Each species 50 count.

# %% [markdown]
# UNI-VARIATE ANALYSIS:
# ---

# %% [markdown]
# We 1.compare species based on sepals
#
# Also 2.we compare species based on petals.
# these are done below....

# %% [markdown]
# COMPARE SPECIES BASED ON SEPALS?
# ---

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',hue='species',data=df)  #scatter plot

# %%
sns.lineplot(x="sepal_length", y="sepal_width", hue="species" ,data=df) #lineplot

# %%
sns.barplot(x="sepal_length", y="sepal_width", hue="species",capsize=.1 ,data=df) #barplot

# %% [markdown]
# SOLUTION:We can see the difference in species based on their sepals.
#
# ---
# we see that iris-setosa has large sepal_width but less sepal_length.when compared iris-setosa have small sepals.
#
# iris-versicolor have an average sepals when compared when to other two species.
#
# iris-virgininca has the large sepals comparitively. we can see than sepal-width is less for iris-virginica but sepal-length is more for iris-virginica

# %% [markdown]
# COMPARE SPECIES BASED ON PETALS?
# ---

# %%
sns.scatterplot(x='petal_length',y='petal_width',hue='species',data=df)  #scatter plot

# %%
sns.lineplot(x='petal_length',y='petal_width',hue='species',data=df) #lineplot

# %%
sns.barplot(x='petal_length',y='petal_width',hue='species',data=df)  #bar plot

# %% [markdown]
# SOLUTION:We used three different plot(scatter plot,lineplot,barplot) to analysze difference in petals of each species.we can see the differnce of petals in each species
#
# ---
# Iris-virginica has the large petals compared to other species.
#
# Iris-versicolor have the medium petals.
#
# Iris-setosa have the small petals when compared to other species

# %% [markdown]
# BI-VARIATE ANALYSIS ON SPECIES:
# ---

# %%
sns.pairplot(df,hue='species')  #pairplot

# %% [markdown]
# Conclusion:we pairplotted all feature that is sepal,petal dimensions for the species commonly
#
# ---
# from the above we can see that iris-setosa is majorly small in most of the features whereas iris-virginica is large and iris-versicolor is medium when compared.

# %% [markdown]
# DISTRIBUTION OF SPECIES:
# ---

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9))                                #boxplot to know about distribution
sns.boxplot( y='petal_width', x= 'species', data=df, orient='v' , ax=axes[0, 0])
sns.boxplot( y='petal_length', x= 'species', data=df, orient='v' , ax=axes[0, 1])
sns.boxplot( y='sepal_length', x= 'species', data=df, orient='v' , ax=axes[1, 0])
sns.boxplot( y='sepal_width', x= 'species', data=df, orient='v', ax=axes[1, 1])
plt.show()

# %% [markdown]
# CONCLUSION:we can see that,
# every species have different features.(we used boxplot to analyze this.)
#
#
# ---
# Iris-virginica has the large petals compared to other species.
#
# Iris-versicolor have the medium petals.
#
# Iris-setosa have the small petals when compared to other species

# %% [markdown]
# HISTOGRAM AND PROBABILITY DENSITY FUNCTION(PDF)
# ---
# with each feature as a variable on x-*axis* and kernel density at y-axis

# %%
import warnings                                     #filtering unwanted warnings
warnings.filterwarnings('ignore')

sns.FacetGrid(df, hue="species", height=5) \
.map(sns.distplot, "sepal_length") \
.add_legend()

sns.FacetGrid(df, hue="species", height=5) \
.map(sns.distplot, "sepal_width") \
.add_legend()

sns.FacetGrid(df, hue="species", height=5) \
.map(sns.distplot, "petal_length") \
.add_legend()

sns.FacetGrid(df, hue="species", height=5) \
.map(sns.distplot, "petal_width") \
.add_legend()
plt.show()

# %% [markdown]
# CONCLUSION:
#
# ---
# Plot 1 shows that there is a significant amount of overlap between the species on sepal length, so it is not an effective Classification feature
#
# Plot 2 shows that there is even higher overlap between the species on sepal width, so it is not an effective Classification feature
#
# Plot 3 shows that petal length is a good Classification feature as it clearly separates the species . The overlap is extremely less (between Versicolor and Virginica) , Setosa is well separated from the rest two
#
# Just like Plot 3, Plot 4 also shows that petal width is a good Classification feature . The overlap is significantly less (between Versicolor and Virginica) , Setosa is well separated from the rest two
